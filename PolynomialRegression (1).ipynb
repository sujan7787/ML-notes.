# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
np.random.rand(10,1)
# Out:
# array([[0.80245328],
#        [0.22216202],
#        [0.58259859],
#        [0.53845727],
#        [0.14553449],
#        [0.72532305],
#        [0.58545915],
#        [0.35879412],
#        [0.73745387],
#        [0.04424922]])

# %%
X = 6 * np.random.rand(100, 1) - 3
y = 0.5 * X**2 + 1.5 * X + 2 + np.random.randn(100, 1)

# %%
print(X)
# Out:
# [[ 0.33928552]
#  [-2.64773043]
#  [ 2.33535648]
#  [-2.417498  ]
#  [-2.00274709]
#  [-1.05226794]
#  [-2.46117247]
#  [-2.23608038]
#  [ 1.94131074]
#  [-1.46621325]
#  [ 1.5335767 ]
#  [ 0.1641156 ]
#  [ 1.64886965]
#  [-0.66048838]
#  [-1.27914766]
#  [-0.22817719]
#  [ 0.41113726]
#  [-0.05640654]
#  [-2.72421699]
#  [-2.45318145]
#  [-0.22033487]
#  [-2.93935797]
#  [ 2.81450327]
#  [ 2.918056  ]
#  [-0.5050749 ]
#  [ 1.82141793]
#  [ 0.08410203]
#  [-1.95291732]
#  [-0.937076  ]
#  [ 2.8701541 ]
#  [ 1.95843229]
#  [ 0.21721622]
#  [ 1.83806885]
#  [ 2.15286863]
#  [-0.26893731]
#  [ 0.08994623]
#  [ 1.09782647]
#  [ 0.80842353]
#  [-0.73420511]
#  [ 1.27779995]
#  [-0.86779492]
#  [-2.99549052]
#  [-2.15964566]
#  [-2.27082957]
#  [ 0.3733363 ]
#  [-2.67821883]
#  [ 2.98954614]
#  [ 1.27030267]
#  [-1.49092172]
#  [ 0.19049599]
#  [-2.09664019]
#  [ 1.06248885]
#  [ 2.24679225]
#  [-2.18806082]
#  [ 2.8181558 ]
#  [-2.87958846]
#  [ 1.14976909]
#  [ 1.46110027]
#  [-1.11604277]
#  [ 1.65750881]
#  [ 1.9236288 ]
#  [-1.19316021]
#  [-0.68358295]
#  [ 0.10575447]
#  [-2.0430331 ]
#  [-1.22414276]
#  [ 1.09407012]
#  [ 1.553935  ]
#  [-2.53236382]
#  [-0.07743653]
#  [ 0.21431037]
#  [ 0.87852841]
#  [-2.08434272]
#  [ 0.62253096]
#  [ 2.85986894]
#  [-1.59015648]
#  [-1.21225505]
#  [ 0.20398104]
#  [-0.8649433 ]
#  [-2.15521497]
#  [-0.19207258]
#  [ 0.44799739]
#  [ 0.44375681]
#  [-2.05451622]
#  [-0.86550267]
#  [-0.47004493]
#  [ 2.25822671]
#  [-0.80087809]
#  [ 0.37087276]
#  [-2.33469601]
#  [ 2.24579605]
#  [ 2.61731124]
#  [ 0.12253616]
#  [-2.47737829]
#  [-2.16737507]
#  [ 2.02406211]
#  [-2.988144  ]
#  [ 1.95443181]
#  [ 1.96200177]
#  [ 0.34680126]]

# %%
y
# Out:
# array([[ 2.78042814e+00],
#        [-2.54410469e-01],
#        [ 7.82616513e+00],
#        [ 2.40043434e+00],
#        [ 3.04126683e+00],
#        [ 2.31521682e+00],
#        [ 6.50473970e-01],
#        [ 1.58338866e+00],
#        [ 5.51464016e+00],
#        [-1.98636561e-01],
#        [ 5.06661129e+00],
#        [ 1.96670165e+00],
#        [ 8.08959345e+00],
#        [ 2.13631605e+00],
#        [ 1.43452523e+00],
#        [ 9.73989440e-01],
#        [ 1.25212238e+00],
#        [ 1.35294344e+00],
#        [ 2.93066293e+00],
#        [ 1.41076602e+00],
#        [ 1.86578914e+00],
#        [ 3.28804888e+00],
#        [ 1.16858653e+01],
#        [ 9.22465816e+00],
#        [ 1.45842885e+00],
#        [ 7.56661956e+00],
#        [ 2.25750303e+00],
#        [-1.90886960e-01],
#        [ 5.57055414e-01],
#        [ 9.84899158e+00],
#        [ 6.12358149e+00],
#        [ 1.08885823e+00],
#        [ 5.52106496e+00],
#        [ 6.34423225e+00],
#        [ 1.98517604e+00],
#        [ 1.69093266e+00],
#        [ 4.33314548e+00],
#        [ 5.36192483e+00],
#        [ 3.26292688e+00],
#        [ 5.11709217e+00],
#        [ 3.35630336e+00],
#        [ 2.26168645e+00],
#        [ 2.51802597e+00],
#        [ 3.14754790e-01],
#        [ 2.70900212e+00],
#        [ 2.46003461e+00],
#        [ 1.06953132e+01],
#        [ 4.83257710e+00],
#        [ 2.90067003e+00],
#        [ 1.96881830e+00],
#        [ 5.82175505e-01],
#        [ 4.01367366e+00],
#        [ 7.29133260e+00],
#        [-4.46890818e-04],
#        [ 1.03758967e+01],
#        [ 1.93588698e+00],
#        [ 4.36532682e+00],
#        [ 6.52129119e+00],
#        [ 1.59209684e+00],
#        [ 4.95038194e+00],
#        [ 7.92606359e+00],
#        [-1.24678348e-01],
#        [ 9.52809703e-01],
#        [ 2.78580912e+00],
#        [ 2.77364383e+00],
#        [ 1.38075216e+00],
#        [ 4.76635170e+00],
#        [ 6.30919254e+00],
#        [ 1.26781000e+00],
#        [ 1.55159782e+00],
#        [ 2.04950292e+00],
#        [ 6.58767989e+00],
#        [ 1.95551038e+00],
#        [ 3.07367402e+00],
#        [ 1.26093902e+01],
#        [ 6.26300446e-01],
#        [ 1.00704149e+00],
#        [ 2.94921303e+00],
#        [ 4.99174568e-01],
#        [ 5.78715083e-01],
#        [ 8.44471562e-01],
#        [ 2.94888484e+00],
#        [ 2.63281593e+00],
#        [ 9.40601137e-01],
#        [-7.31490494e-02],
#        [ 2.29591478e+00],
#        [ 7.10317777e+00],
#        [ 2.55718114e-01],
#        [ 5.21728482e+00],
#        [ 1.32235583e+00],
#        [ 8.40728931e+00],
#        [ 8.64736282e+00],
#        [ 2.70225448e+00],
#        [ 8.45435810e-01],
#        [ 3.03417294e+00],
#        [ 5.61368958e+00],
#        [ 2.64901854e+00],
#        [ 8.81318321e+00],
#        [ 6.96364137e+00],
#        [ 2.00423540e+00]])

# %%
X.shape, y.shape
# Out:
# ((100, 1), (100, 1))

# %%
# quadratic equation used - y = 0.5 * X**2 + 1.5*X + 2 + outliers
plt.scatter(X, y, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.show()

# %%
X
# Out:
# array([[ 0.33928552],
#        [-2.64773043],
#        [ 2.33535648],
#        [-2.417498  ],
#        [-2.00274709],
#        [-1.05226794],
#        [-2.46117247],
#        [-2.23608038],
#        [ 1.94131074],
#        [-1.46621325],
#        [ 1.5335767 ],
#        [ 0.1641156 ],
#        [ 1.64886965],
#        [-0.66048838],
#        [-1.27914766],
#        [-0.22817719],
#        [ 0.41113726],
#        [-0.05640654],
#        [-2.72421699],
#        [-2.45318145],
#        [-0.22033487],
#        [-2.93935797],
#        [ 2.81450327],
#        [ 2.918056  ],
#        [-0.5050749 ],
#        [ 1.82141793],
#        [ 0.08410203],
#        [-1.95291732],
#        [-0.937076  ],
#        [ 2.8701541 ],
#        [ 1.95843229],
#        [ 0.21721622],
#        [ 1.83806885],
#        [ 2.15286863],
#        [-0.26893731],
#        [ 0.08994623],
#        [ 1.09782647],
#        [ 0.80842353],
#        [-0.73420511],
#        [ 1.27779995],
#        [-0.86779492],
#        [-2.99549052],
#        [-2.15964566],
#        [-2.27082957],
#        [ 0.3733363 ],
#        [-2.67821883],
#        [ 2.98954614],
#        [ 1.27030267],
#        [-1.49092172],
#        [ 0.19049599],
#        [-2.09664019],
#        [ 1.06248885],
#        [ 2.24679225],
#        [-2.18806082],
#        [ 2.8181558 ],
#        [-2.87958846],
#        [ 1.14976909],
#        [ 1.46110027],
#        [-1.11604277],
#        [ 1.65750881],
#        [ 1.9236288 ],
#        [-1.19316021],
#        [-0.68358295],
#        [ 0.10575447],
#        [-2.0430331 ],
#        [-1.22414276],
#        [ 1.09407012],
#        [ 1.553935  ],
#        [-2.53236382],
#        [-0.07743653],
#        [ 0.21431037],
#        [ 0.87852841],
#        [-2.08434272],
#        [ 0.62253096],
#        [ 2.85986894],
#        [-1.59015648],
#        [-1.21225505],
#        [ 0.20398104],
#        [-0.8649433 ],
#        [-2.15521497],
#        [-0.19207258],
#        [ 0.44799739],
#        [ 0.44375681],
#        [-2.05451622],
#        [-0.86550267],
#        [-0.47004493],
#        [ 2.25822671],
#        [-0.80087809],
#        [ 0.37087276],
#        [-2.33469601],
#        [ 2.24579605],
#        [ 2.61731124],
#        [ 0.12253616],
#        [-2.47737829],
#        [-2.16737507],
#        [ 2.02406211],
#        [-2.988144  ],
#        [ 1.95443181],
#        [ 1.96200177],
#        [ 0.34680126]])

# %%
y
# Out:
# array([[ 2.78042814e+00],
#        [-2.54410469e-01],
#        [ 7.82616513e+00],
#        [ 2.40043434e+00],
#        [ 3.04126683e+00],
#        [ 2.31521682e+00],
#        [ 6.50473970e-01],
#        [ 1.58338866e+00],
#        [ 5.51464016e+00],
#        [-1.98636561e-01],
#        [ 5.06661129e+00],
#        [ 1.96670165e+00],
#        [ 8.08959345e+00],
#        [ 2.13631605e+00],
#        [ 1.43452523e+00],
#        [ 9.73989440e-01],
#        [ 1.25212238e+00],
#        [ 1.35294344e+00],
#        [ 2.93066293e+00],
#        [ 1.41076602e+00],
#        [ 1.86578914e+00],
#        [ 3.28804888e+00],
#        [ 1.16858653e+01],
#        [ 9.22465816e+00],
#        [ 1.45842885e+00],
#        [ 7.56661956e+00],
#        [ 2.25750303e+00],
#        [-1.90886960e-01],
#        [ 5.57055414e-01],
#        [ 9.84899158e+00],
#        [ 6.12358149e+00],
#        [ 1.08885823e+00],
#        [ 5.52106496e+00],
#        [ 6.34423225e+00],
#        [ 1.98517604e+00],
#        [ 1.69093266e+00],
#        [ 4.33314548e+00],
#        [ 5.36192483e+00],
#        [ 3.26292688e+00],
#        [ 5.11709217e+00],
#        [ 3.35630336e+00],
#        [ 2.26168645e+00],
#        [ 2.51802597e+00],
#        [ 3.14754790e-01],
#        [ 2.70900212e+00],
#        [ 2.46003461e+00],
#        [ 1.06953132e+01],
#        [ 4.83257710e+00],
#        [ 2.90067003e+00],
#        [ 1.96881830e+00],
#        [ 5.82175505e-01],
#        [ 4.01367366e+00],
#        [ 7.29133260e+00],
#        [-4.46890818e-04],
#        [ 1.03758967e+01],
#        [ 1.93588698e+00],
#        [ 4.36532682e+00],
#        [ 6.52129119e+00],
#        [ 1.59209684e+00],
#        [ 4.95038194e+00],
#        [ 7.92606359e+00],
#        [-1.24678348e-01],
#        [ 9.52809703e-01],
#        [ 2.78580912e+00],
#        [ 2.77364383e+00],
#        [ 1.38075216e+00],
#        [ 4.76635170e+00],
#        [ 6.30919254e+00],
#        [ 1.26781000e+00],
#        [ 1.55159782e+00],
#        [ 2.04950292e+00],
#        [ 6.58767989e+00],
#        [ 1.95551038e+00],
#        [ 3.07367402e+00],
#        [ 1.26093902e+01],
#        [ 6.26300446e-01],
#        [ 1.00704149e+00],
#        [ 2.94921303e+00],
#        [ 4.99174568e-01],
#        [ 5.78715083e-01],
#        [ 8.44471562e-01],
#        [ 2.94888484e+00],
#        [ 2.63281593e+00],
#        [ 9.40601137e-01],
#        [-7.31490494e-02],
#        [ 2.29591478e+00],
#        [ 7.10317777e+00],
#        [ 2.55718114e-01],
#        [ 5.21728482e+00],
#        [ 1.32235583e+00],
#        [ 8.40728931e+00],
#        [ 8.64736282e+00],
#        [ 2.70225448e+00],
#        [ 8.45435810e-01],
#        [ 3.03417294e+00],
#        [ 5.61368958e+00],
#        [ 2.64901854e+00],
#        [ 8.81318321e+00],
#        [ 6.96364137e+00],
#        [ 2.00423540e+00]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
## Simple Linear Regression
from sklearn.linear_model import LinearRegression
lin_reg = LinearRegression()

# %%
lin_reg
# Out:
# LinearRegression()

# %%
lin_reg.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score
score = r2_score(y_test, lin_reg.predict(X_test))
print('R2 score for Linear Regression:', score)
# Out:
# R2 score for Linear Regression: 0.4516964893617228

# %%
## Visualize this model
plt.plot(X_train, lin_reg.predict(X_train), color = 'r')
plt.scatter(X_train, y_train, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.show()

# %%
## Visualize this model
plt.plot(X_test, lin_reg.predict(X_test), color = 'r')
plt.scatter(X_test, y_test, color = 'g')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
# Out:
# Text(0, 0.5, 'y dataset')

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#         -1.06966971e-02,  2.35685535e-03, -5.19297415e-04],
#        [ 1.00000000e+00,  1.92362880e+00,  3.70034775e+00,
#          7.11809549e+00,  1.36925735e+01,  2.63394286e+01],
#        [ 1.00000000e+00,  8.78528415e-01,  7.71812175e-01,
#          6.78058927e-01,  5.95694034e-01,  5.23334135e-01],
#        [ 1.00000000e+00, -1.27914766e+00,  1.63621872e+00,
#         -2.09296534e+00,  2.67721171e+00, -3.42454909e+00],
#        [ 1.00000000e+00,  1.22536160e-01,  1.50151106e-02,
#          1.83989400e-03,  2.25453546e-04,  2.76262118e-05],
#        [ 1.00000000e+00,  1.06248885e+00,  1.12888255e+00,
#          1.19942512e+00,  1.27437582e+00,  1.35401010e+00]])

# %%
from sklearn.metrics import r2_score
lin_reg2 = LinearRegression()
lin_reg2.fit(X_train_poly, y_train)
y_pred = lin_reg2.predict(X_test_poly)
score = r2_score(y_test, y_pred)
print('R2 score for Polynomial Regression:', score)
# Out:
# R2 score for Polynomial Regression: 0.8242382800198633

# %%
print('Coefficients:', lin_reg2.coef_)
# Out:
# Coefficients: [[ 0.          1.59576386  0.44448636 -0.03659719  0.00262643  0.00221427]]

# %%
print('Intercept:', lin_reg2.intercept_)
# Out:
# Intercept: [2.24174065]

# %%
plt.scatter(X_train, lin_reg2.predict(X_train_poly), color = 'r')
plt.scatter(X_train, y_train, color = 'g')

# %%
# Prediction of new data set
X_new = np.linspace(-3, 3, 200).reshape(200, 1)

X_new_poly = poly.transform(X_new)
X_new_poly
# Out:
# array([[   1.        ,   -3.        ,    9.        ,  -27.        ,
#           81.        , -243.        ],
#        [   1.        ,   -2.96984925,    8.82000455,  -26.19408385,
#           77.79248018, -231.03193862],
#        [   1.        ,   -2.93969849,    8.64182723,  -25.40436647,
#           74.68117781, -219.54014584],
#        ...,
#        [   1.        ,    2.93969849,    8.64182723,   25.40436647,
#           74.68117781,  219.54014584],
#        [   1.        ,    2.96984925,    8.82000455,   26.19408385,
#           77.79248018,  231.03193862],
#        [   1.        ,    3.        ,    9.        ,   27.        ,
#           81.        ,  243.        ]])

# %%
y_new = lin_reg2.predict(X_new_poly)
plt.plot(X_new, y_new, color = 'r', label = 'Predictions')
plt.plot(X_train, y_train, 'g.', label = 'Training data')
plt.plot(X_test, y_test, 'b.', label = 'Test data')
plt.xlabel('X dataset')
plt.ylabel('y dataset')
plt.legend()
plt.show()

# %% [markdown]
# Pipelining

# %%
from sklearn.pipeline import Pipeline

# %%
def poly_regression(degree):
    X_new = np.linspace(-3, 3, 200).reshape(200, 1)
    poly_features = PolynomialFeatures(degree = degree)
    lin_reg = LinearRegression()
    poly_regression = Pipeline([
        ('poly_features', poly_features),
        ('lin_reg', lin_reg)
    ])

    poly_regression.fit(X_train, y_train)
    y_pred_new = poly_regression.predict(X_new)

    # Plotting prediction line
    plt.plot(X_new, y_pred_new, label = 'Predictions', color = 'r')
    plt.plot(X_train, y_train, 'g.', label = 'Training data')
    plt.plot(X_test, y_test, 'b.', label = 'Test data')
    plt.legend(loc = "upper left")
    plt.xlabel('X dataset')
    plt.ylabel('y dataset')
    plt.show()

# %%
poly_regression(3)

# %%
poly_regression(0)

# %%
poly_regression(1)

# %%
poly_regression(2)

# %%
poly_regression(3)

# %%
poly_regression(10)

# %%
poly_regression(12)
